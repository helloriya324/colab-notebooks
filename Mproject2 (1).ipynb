# %%
#EXPLORATORY DATA ANALYSIS - MACHINE LEARNING FROM CARDIO GOOD FITNESS

# %%
#1.Take the data and create dataframe
import pandas as pd
df = pd.read_csv('/content/CardioGoodFitness.csv')
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ..     ...
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180
#
# [180 rows x 9 columns]

# %%
df.shape #180 rows and 9 columns
# Out:
# (180, 9)

# %%
df.size #Total number of elements in dataframe
# Out:
# 1620

# %%
df.info() #It gives the complete information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
#to check the null values officially
df.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
#I want to find out the exact count of unique elements in each and every column
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
#VISUALISATION - SEABORN
#THIS VISUALISATION TELLS US ABOUT THE CAEDIO FITNESS OF THE PEOPLE
import seaborn as sns #import the library
sns.countplot(x = 'MaritalStatus',data = df)
#you can change x into y for horizontal view of bars

# %%
#I want the exact count of no of people with cardio fitness
df['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
df.MaritalStatus.value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
df.groupby('MaritalStatus').size()
# Out:
# MaritalStatus
# Partnered    107
# Single        73
# dtype: int64

# %%
#I want to know the gender of the people with cardio fitness
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
df.groupby('Gender').size()
# Out:
# Gender
# Female     76
# Male      104
# dtype: int64

# %%
#Now let us divide the Age column's data into 4 different categories

young = np.sum((df['Age']>=0)&(df['Age']<20)) #0 to 19
adult = np.sum((df['Age']>=20)&(df['Age']<40)) #20 to 39
midage = np.sum((df['Age']>=40)&(df['Age']<60)) #40 to 59
old = np.sum((df['Age']>=60))#60 and above
print(young,adult,midage,old)
# Out:
# 5 158 17 0

# %%
#The age column has got 714 values
5+158+17+0
# Out:
# 180

# %%
#I want to find out the Age of the youngest Passenger
np.min(df['Age'])
# Out:
# 18

# %%
#I want to find out the Age of the eldest Passenger
np.max(df['Age'])
# Out:
# 50
